# %%
import sys
sys.path.append('../src')

# %%
import Ejercicio10
# Out:
# Ronda 1 - Entrada:
# Ganador: Camila (26 pts)
# Cocinero     Puntaje
# -------------------------
# Camila       26
# Valentina    24
# Lucía        24
# Mateo        22
# Santiago     19
#
# Ronda 2 - Plato principal:
# Ganador: Valentina (26 pts)
# Cocinero     Puntaje
# -------------------------
# Valentina    26
# Santiago     25
# Mateo        24
# Lucía        22
# Camila       20
#
# Ronda 3 - Postre:
# Ganador: Lucía (27 pts)
# Cocinero     Puntaje
# -------------------------
# Lucía        27
# Mateo        26
# Camila       24
# Valentina    22
# Santiago     20
#
# Ronda 4 - Cocina internacional:
# Ganador: Valentina (26 pts)
# Cocinero     Puntaje
# -------------------------
# Valentina    26
# Camila       25
# Santiago     24
# Lucía        22
# Mateo        20
#
# Ronda 5 - Final libre:
# Ganador: Santiago (27 pts)
# Cocinero     Puntaje
# -------------------------
# Santiago     27
# Valentina    26
# Mateo        25
# Lucía        23
# Camila       21
#
#
# ...
